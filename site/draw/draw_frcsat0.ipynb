# %%
data1 = {'pathname': f'/share/home/dq076/data/cases/site/{case}/{siteid}/postdata/',
    'filename': f'{siteid}_hist_{yrstt}-{yrend}.nc',
    'varname': 'f_ch4_surf_flux_tot',
    'unit': 'nmol CH4 m-2 s-1'
         }
