# %%
import subprocess
import os
from joblib import Parallel, delayed
import glob
from concurrent.futures import ProcessPoolExecutor, as_completed  # 切换到 ProcessPoolExecutor 以支持实时进度

def load_environment(env_file):
    cmd = f'bash -c "source {env_file} && env"'
    result = subprocess.run(cmd, shell=True, capture_output=True, text=True)
    
    new_env = {}
    for line in result.stdout.strip().split('\n'):
        if '=' in line:
            key, value = line.split('=', 1)
            if not key.startswith('BASH_FUNC_'):
                new_env[key] = value
    
    os.environ.update(new_env)
    return os.environ.copy()

def run_colm(run_path, nml_path, log_path, nml_name, updated_env):
    """
    处理单个 nml 文件，返回成功/失败状态（不打印进度，由主脚本处理）。
    """
    nml_file = f'{nml_path}{nml_name}.nml'
    log_file = f'{log_path}{nml_name}.txt'
    
    try:
        # 用 'w' 模式打开文件，重置内容
        with open(log_file, 'w', encoding='utf-8') as log:
            log.write(f"=== 处理 {nml_name}.nml ===\n")
            log.flush()
            
            commands = [
                [f'{run_path}mksrfdata.x', nml_file],
                [f'{run_path}mkinidata.x', nml_file],
                [f'{run_path}colm.x', nml_file]
            ]
            
            for cmd in commands:
                log.write(f"执行命令: {' '.join(cmd)}\n")
                log.flush()
                
                subprocess.run(cmd, 
                               env=updated_env, 
                               stdout=log, 
                               stderr=subprocess.STDOUT, 
                               text=True)
                
                log.write("\n" + "="*50 + "\n")
                log.flush()
            
            log.write(f"=== {nml_name} 处理完成 ===\n")
            log.flush()
        
        return True  # 成功
    except Exception as e:
        # 如果失败，也记录到日志
        with open(log_file, 'w', encoding='utf-8') as log:
            log.write(f"=== {nml_name}.nml 处理失败: {str(e)} ===\n")
        return False

if __name__ == "__main__":
    forcing ='FLUXNET-CH4'
    mode ='no_spin_up'

    env_file = '/share/home/dq089/soft/gnu-env'
    run_path = '/share/home/dq076/mode/ME/CoLM202X_CH4_s/run/'

    nml_path = f'{run_path}site/{forcing}/{mode}/'
    log_path = f'{nml_path}logs/'  
    os.makedirs(log_path, exist_ok=True)

    updated_env = load_environment(env_file)
    nml_files = glob.glob(f'{nml_path}*.nml')
    nml_names = [os.path.splitext(os.path.basename(nml_file))[0] for nml_file in nml_files]
    print(f"发现 {len(nml_files)} 个 .nml 文件：{nml_names}")
    
    # 切换到 ProcessPoolExecutor 以支持 as_completed 实时进度
    max_workers = min(24, os.cpu_count() or 1)
    with ProcessPoolExecutor(max_workers=max_workers) as executor:
        # 提交所有任务，返回 future 对象
        future_to_nml = {
            executor.submit(run_colm, run_path, nml_path, log_path, nml_name, updated_env): nml_name
            for nml_name in nml_names
        }
        
        # 维护剩余任务集合
        remaining_nml = set(nml_names)
        completed_count = 0
        
        # 实时监控完成
        for future in as_completed(future_to_nml):
            nml_name = future_to_nml[future]
            try:
                success = future.result()
                if success:
                    completed_count += 1
                remaining_nml.discard(nml_name)  # 移除已完成（无论成功/失败）
                
                # 打印进度：总数 + 剩余列表
                print(f"=== {nml_name} 处理完成（成功: {success}) ===")
                print(f"已完成总数: {completed_count}/{len(nml_names)}")
                if remaining_nml:
                    print(f"剩余未处理: {sorted(list(remaining_nml))}")
                else:
                    print("所有任务已完成！")
                print("-" * 50)
                
            except Exception as exc:
                print(f"{nml_name} 执行异常: {exc}")
                remaining_nml.discard(nml_name)
                completed_count += 1  # 视作完成（失败）
                print(f"已完成总数: {completed_count}/{len(nml_names)}")
                if remaining_nml:
                    print(f"剩余未处理: {sorted(list(remaining_nml))}")
                print("-" * 50)
    
    print("批量处理结束。")

# %%
import subprocess
import os
from joblib import Parallel, delayed
import glob
from concurrent.futures import ProcessPoolExecutor, as_completed  # 切换到 ProcessPoolExecutor 以支持实时进度

def load_environment(env_file):
    cmd = f'bash -c "source {env_file} && env"'
    result = subprocess.run(cmd, shell=True, capture_output=True, text=True)
    
    new_env = {}
    for line in result.stdout.strip().split('\n'):
        if '=' in line:
            key, value = line.split('=', 1)
            if not key.startswith('BASH_FUNC_'):
                new_env[key] = value
    
    os.environ.update(new_env)
    return os.environ.copy()

def run_colm(run_path, nml_path, log_path, nml_name, updated_env):
    """
    处理单个 nml 文件，返回成功/失败状态（不打印进度，由主脚本处理）。
    """
    nml_file = f'{nml_path}{nml_name}.nml'
    log_file = f'{log_path}{nml_name}.txt'
    
    try:
        # 用 'w' 模式打开文件，重置内容
        with open(log_file, 'w', encoding='utf-8') as log:
            log.write(f"=== 处理 {nml_name}.nml ===\n")
            log.flush()
            
            commands = [
                # [f'{run_path}mksrfdata.x', nml_file],
                # [f'{run_path}mkinidata.x', nml_file],
                [f'{run_path}colm.x', nml_file]
            ]
            
            for cmd in commands:
                log.write(f"执行命令: {' '.join(cmd)}\n")
                log.flush()
                
                subprocess.run(cmd, 
                               env=updated_env, 
                               stdout=log, 
                               stderr=subprocess.STDOUT, 
                               text=True)
                
                log.write("\n" + "="*50 + "\n")
                log.flush()
            
            log.write(f"=== {nml_name} 处理完成 ===\n")
            log.flush()
        
        return True  # 成功
    except Exception as e:
        # 如果失败，也记录到日志
        with open(log_file, 'w', encoding='utf-8') as log:
            log.write(f"=== {nml_name}.nml 处理失败: {str(e)} ===\n")
        return False

if __name__ == "__main__":
    forcing ='FLUXNET-CH4'
    mode ='spin_up_80yr'

    env_file = '/share/home/dq089/soft/gnu-env'
    run_path = '/share/home/dq076/mode/ME/CoLM202X_CH4_s/run/'

    nml_path = f'{run_path}site/{forcing}/{mode}/'
    log_path = f'{nml_path}logs/'  
    os.makedirs(log_path, exist_ok=True)

    updated_env = load_environment(env_file)
    nml_files = glob.glob(f'{nml_path}*.nml')
    nml_names = [os.path.splitext(os.path.basename(nml_file))[0] for nml_file in nml_files]
    print(f"发现 {len(nml_files)} 个 .nml 文件：{nml_names}")
    
    # 切换到 ProcessPoolExecutor 以支持 as_completed 实时进度
    max_workers = min(24, os.cpu_count() or 1)
    with ProcessPoolExecutor(max_workers=max_workers) as executor:
        # 提交所有任务，返回 future 对象
        future_to_nml = {
            executor.submit(run_colm, run_path, nml_path, log_path, nml_name, updated_env): nml_name
            for nml_name in nml_names
        }
        
        # 维护剩余任务集合
        remaining_nml = set(nml_names)
        completed_count = 0
        
        # 实时监控完成
        for future in as_completed(future_to_nml):
            nml_name = future_to_nml[future]
            try:
                success = future.result()
                if success:
                    completed_count += 1
                remaining_nml.discard(nml_name)  # 移除已完成（无论成功/失败）
                
                # 打印进度：总数 + 剩余列表
                print(f"=== {nml_name} 处理完成（成功: {success}) ===")
                print(f"已完成总数: {completed_count}/{len(nml_names)}")
                if remaining_nml:
                    print(f"剩余未处理: {sorted(list(remaining_nml))}")
                else:
                    print("所有任务已完成！")
                print("-" * 50)
                
            except Exception as exc:
                print(f"{nml_name} 执行异常: {exc}")
                remaining_nml.discard(nml_name)
                completed_count += 1  # 视作完成（失败）
                print(f"已完成总数: {completed_count}/{len(nml_names)}")
                if remaining_nml:
                    print(f"剩余未处理: {sorted(list(remaining_nml))}")
                print("-" * 50)
    
    print("批量处理结束。")
# Out:
# 发现 79 个 .nml 文件：['US-Tw1', 'US-Tw4', 'US-Uaf', 'ID-Pag', 'US-MRM', 'HK-MPM', 'CH-Cha', 'US-HRA', 'US-ICs', 'FI-Lom', 'US-EML', 'KR-CRK', 'IT-Cas', 'CH-Dav', 'FI-Si2', 'US-LA2', 'US-LA1', 'US-Tw5', 'JP-Mse', 'US-Myb', 'AT-Neu', 'US-NGC', 'US-EDN', 'MY-MLM', 'RU-Ch2', 'DE-Dgw', 'US-ORv', 'DE-SfN', 'US-BZS', 'US-CRT', 'US-A10', 'US-StJ', 'US-Sne', 'US-DPW', 'CA-SCB', 'RU-Cok', 'PH-RiF', 'FR-LGt', 'US-NGB', 'CA-SCC', 'US-Snd', 'RU-Che', 'NZ-Kop', 'US-Bi2', 'BW-Gum', 'US-Srr', 'US-Tw3', 'US-Ho1', 'BR-Npw', 'JP-SwL', 'JP-BBY', 'US-Pfa', 'US-BZF', 'DE-Hte', 'FI-Hyy', 'US-A03', 'US-Los', 'US-Bi1', 'US-Ivo', 'US-Bes', 'RU-Fy2', 'US-MAC', 'US-Twt', 'US-WPT', 'US-BZB', 'US-HRC', 'NL-Hor', 'CH-Oe2', 'DE-Zrk', 'CN-Hgu', 'US-Beo', 'US-NC4', 'BW-Nxr', 'IT-BCi', 'SE-Deg', 'US-OWC', 'FI-Sii', 'US-Atq', 'UK-LBT']
# === ID-Pag 处理完成（成功: True) ===
# 已完成总数: 1/79
# 剩余未处理: ['AT-Neu', 'BR-Npw', 'BW-Gum', 'BW-Nxr', 'CA-SCB', 'CA-SCC', 'CH-Cha', 'CH-Dav', 'CH-Oe2', 'CN-Hgu', 'DE-Dgw', 'DE-Hte', 'DE-SfN', 'DE-Zrk', 'FI-Hyy', 'FI-Lom', 'FI-Si2', 'FI-Sii', 'FR-LGt', 'HK-MPM', 'IT-BCi', 'IT-Cas', 'JP-BBY', 'JP-Mse', 'JP-SwL', 'KR-CRK', 'MY-MLM', 'NL-Hor', 'NZ-Kop', 'PH-RiF', 'RU-Ch2', 'RU-Che', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-BZS', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-Bi2', 'US-CRT', 'US-DPW', 'US-EDN', 'US-EML', 'US-HRA', 'US-HRC', 'US-Ho1', 'US-ICs', 'US-Ivo', 'US-LA1', 'US-LA2', 'US-Los', 'US-MAC', 'US-MRM', 'US-Myb', 'US-NC4', 'US-NGB', 'US-NGC', 'US-ORv', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Sne', 'US-Srr', 'US-StJ', 'US-Tw1', 'US-Tw3', 'US-Tw4', 'US-Tw5', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === US-HRA 处理完成（成功: True) ===
# 已完成总数: 2/79
# 剩余未处理: ['AT-Neu', 'BR-Npw', 'BW-Gum', 'BW-Nxr', 'CA-SCB', 'CA-SCC', 'CH-Cha', 'CH-Dav', 'CH-Oe2', 'CN-Hgu', 'DE-Dgw', 'DE-Hte', 'DE-SfN', 'DE-Zrk', 'FI-Hyy', 'FI-Lom', 'FI-Si2', 'FI-Sii', 'FR-LGt', 'HK-MPM', 'IT-BCi', 'IT-Cas', 'JP-BBY', 'JP-Mse', 'JP-SwL', 'KR-CRK', 'MY-MLM', 'NL-Hor', 'NZ-Kop', 'PH-RiF', 'RU-Ch2', 'RU-Che', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-BZS', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-Bi2', 'US-CRT', 'US-DPW', 'US-EDN', 'US-EML', 'US-HRC', 'US-Ho1', 'US-ICs', 'US-Ivo', 'US-LA1', 'US-LA2', 'US-Los', 'US-MAC', 'US-MRM', 'US-Myb', 'US-NC4', 'US-NGB', 'US-NGC', 'US-ORv', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Sne', 'US-Srr', 'US-StJ', 'US-Tw1', 'US-Tw3', 'US-Tw4', 'US-Tw5', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === DE-Dgw 处理完成（成功: True) ===
# 已完成总数: 3/79
# 剩余未处理: ['AT-Neu', 'BR-Npw', 'BW-Gum', 'BW-Nxr', 'CA-SCB', 'CA-SCC', 'CH-Cha', 'CH-Dav', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-SfN', 'DE-Zrk', 'FI-Hyy', 'FI-Lom', 'FI-Si2', 'FI-Sii', 'FR-LGt', 'HK-MPM', 'IT-BCi', 'IT-Cas', 'JP-BBY', 'JP-Mse', 'JP-SwL', 'KR-CRK', 'MY-MLM', 'NL-Hor', 'NZ-Kop', 'PH-RiF', 'RU-Ch2', 'RU-Che', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-BZS', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-Bi2', 'US-CRT', 'US-DPW', 'US-EDN', 'US-EML', 'US-HRC', 'US-Ho1', 'US-ICs', 'US-Ivo', 'US-LA1', 'US-LA2', 'US-Los', 'US-MAC', 'US-MRM', 'US-Myb', 'US-NC4', 'US-NGB', 'US-NGC', 'US-ORv', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Sne', 'US-Srr', 'US-StJ', 'US-Tw1', 'US-Tw3', 'US-Tw4', 'US-Tw5', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === US-EDN 处理完成（成功: True) ===
# 已完成总数: 4/79
# 剩余未处理: ['AT-Neu', 'BR-Npw', 'BW-Gum', 'BW-Nxr', 'CA-SCB', 'CA-SCC', 'CH-Cha', 'CH-Dav', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-SfN', 'DE-Zrk', 'FI-Hyy', 'FI-Lom', 'FI-Si2', 'FI-Sii', 'FR-LGt', 'HK-MPM', 'IT-BCi', 'IT-Cas', 'JP-BBY', 'JP-Mse', 'JP-SwL', 'KR-CRK', 'MY-MLM', 'NL-Hor', 'NZ-Kop', 'PH-RiF', 'RU-Ch2', 'RU-Che', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-BZS', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-Bi2', 'US-CRT', 'US-DPW', 'US-EML', 'US-HRC', 'US-Ho1', 'US-ICs', 'US-Ivo', 'US-LA1', 'US-LA2', 'US-Los', 'US-MAC', 'US-MRM', 'US-Myb', 'US-NC4', 'US-NGB', 'US-NGC', 'US-ORv', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Sne', 'US-Srr', 'US-StJ', 'US-Tw1', 'US-Tw3', 'US-Tw4', 'US-Tw5', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === US-NGC 处理完成（成功: True) ===
# 已完成总数: 5/79
# 剩余未处理: ['AT-Neu', 'BR-Npw', 'BW-Gum', 'BW-Nxr', 'CA-SCB', 'CA-SCC', 'CH-Cha', 'CH-Dav', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-SfN', 'DE-Zrk', 'FI-Hyy', 'FI-Lom', 'FI-Si2', 'FI-Sii', 'FR-LGt', 'HK-MPM', 'IT-BCi', 'IT-Cas', 'JP-BBY', 'JP-Mse', 'JP-SwL', 'KR-CRK', 'MY-MLM', 'NL-Hor', 'NZ-Kop', 'PH-RiF', 'RU-Ch2', 'RU-Che', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-BZS', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-Bi2', 'US-CRT', 'US-DPW', 'US-EML', 'US-HRC', 'US-Ho1', 'US-ICs', 'US-Ivo', 'US-LA1', 'US-LA2', 'US-Los', 'US-MAC', 'US-MRM', 'US-Myb', 'US-NC4', 'US-NGB', 'US-ORv', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Sne', 'US-Srr', 'US-StJ', 'US-Tw1', 'US-Tw3', 'US-Tw4', 'US-Tw5', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === US-Tw5 处理完成（成功: True) ===
# 已完成总数: 6/79
# 剩余未处理: ['AT-Neu', 'BR-Npw', 'BW-Gum', 'BW-Nxr', 'CA-SCB', 'CA-SCC', 'CH-Cha', 'CH-Dav', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-SfN', 'DE-Zrk', 'FI-Hyy', 'FI-Lom', 'FI-Si2', 'FI-Sii', 'FR-LGt', 'HK-MPM', 'IT-BCi', 'IT-Cas', 'JP-BBY', 'JP-Mse', 'JP-SwL', 'KR-CRK', 'MY-MLM', 'NL-Hor', 'NZ-Kop', 'PH-RiF', 'RU-Ch2', 'RU-Che', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-BZS', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-Bi2', 'US-CRT', 'US-DPW', 'US-EML', 'US-HRC', 'US-Ho1', 'US-ICs', 'US-Ivo', 'US-LA1', 'US-LA2', 'US-Los', 'US-MAC', 'US-MRM', 'US-Myb', 'US-NC4', 'US-NGB', 'US-ORv', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Sne', 'US-Srr', 'US-StJ', 'US-Tw1', 'US-Tw3', 'US-Tw4', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === JP-Mse 处理完成（成功: True) ===
# 已完成总数: 7/79
# 剩余未处理: ['AT-Neu', 'BR-Npw', 'BW-Gum', 'BW-Nxr', 'CA-SCB', 'CA-SCC', 'CH-Cha', 'CH-Dav', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-SfN', 'DE-Zrk', 'FI-Hyy', 'FI-Lom', 'FI-Si2', 'FI-Sii', 'FR-LGt', 'HK-MPM', 'IT-BCi', 'IT-Cas', 'JP-BBY', 'JP-SwL', 'KR-CRK', 'MY-MLM', 'NL-Hor', 'NZ-Kop', 'PH-RiF', 'RU-Ch2', 'RU-Che', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-BZS', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-Bi2', 'US-CRT', 'US-DPW', 'US-EML', 'US-HRC', 'US-Ho1', 'US-ICs', 'US-Ivo', 'US-LA1', 'US-LA2', 'US-Los', 'US-MAC', 'US-MRM', 'US-Myb', 'US-NC4', 'US-NGB', 'US-ORv', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Sne', 'US-Srr', 'US-StJ', 'US-Tw1', 'US-Tw3', 'US-Tw4', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === US-LA2 处理完成（成功: True) ===
# 已完成总数: 8/79
# 剩余未处理: ['AT-Neu', 'BR-Npw', 'BW-Gum', 'BW-Nxr', 'CA-SCB', 'CA-SCC', 'CH-Cha', 'CH-Dav', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-SfN', 'DE-Zrk', 'FI-Hyy', 'FI-Lom', 'FI-Si2', 'FI-Sii', 'FR-LGt', 'HK-MPM', 'IT-BCi', 'IT-Cas', 'JP-BBY', 'JP-SwL', 'KR-CRK', 'MY-MLM', 'NL-Hor', 'NZ-Kop', 'PH-RiF', 'RU-Ch2', 'RU-Che', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-BZS', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-Bi2', 'US-CRT', 'US-DPW', 'US-EML', 'US-HRC', 'US-Ho1', 'US-ICs', 'US-Ivo', 'US-LA1', 'US-Los', 'US-MAC', 'US-MRM', 'US-Myb', 'US-NC4', 'US-NGB', 'US-ORv', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Sne', 'US-Srr', 'US-StJ', 'US-Tw1', 'US-Tw3', 'US-Tw4', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === US-LA1 处理完成（成功: True) ===
# 已完成总数: 9/79
# 剩余未处理: ['AT-Neu', 'BR-Npw', 'BW-Gum', 'BW-Nxr', 'CA-SCB', 'CA-SCC', 'CH-Cha', 'CH-Dav', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-SfN', 'DE-Zrk', 'FI-Hyy', 'FI-Lom', 'FI-Si2', 'FI-Sii', 'FR-LGt', 'HK-MPM', 'IT-BCi', 'IT-Cas', 'JP-BBY', 'JP-SwL', 'KR-CRK', 'MY-MLM', 'NL-Hor', 'NZ-Kop', 'PH-RiF', 'RU-Ch2', 'RU-Che', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-BZS', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-Bi2', 'US-CRT', 'US-DPW', 'US-EML', 'US-HRC', 'US-Ho1', 'US-ICs', 'US-Ivo', 'US-Los', 'US-MAC', 'US-MRM', 'US-Myb', 'US-NC4', 'US-NGB', 'US-ORv', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Sne', 'US-Srr', 'US-StJ', 'US-Tw1', 'US-Tw3', 'US-Tw4', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === US-MRM 处理完成（成功: True) ===
# 已完成总数: 10/79
# 剩余未处理: ['AT-Neu', 'BR-Npw', 'BW-Gum', 'BW-Nxr', 'CA-SCB', 'CA-SCC', 'CH-Cha', 'CH-Dav', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-SfN', 'DE-Zrk', 'FI-Hyy', 'FI-Lom', 'FI-Si2', 'FI-Sii', 'FR-LGt', 'HK-MPM', 'IT-BCi', 'IT-Cas', 'JP-BBY', 'JP-SwL', 'KR-CRK', 'MY-MLM', 'NL-Hor', 'NZ-Kop', 'PH-RiF', 'RU-Ch2', 'RU-Che', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-BZS', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-Bi2', 'US-CRT', 'US-DPW', 'US-EML', 'US-HRC', 'US-Ho1', 'US-ICs', 'US-Ivo', 'US-Los', 'US-MAC', 'US-Myb', 'US-NC4', 'US-NGB', 'US-ORv', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Sne', 'US-Srr', 'US-StJ', 'US-Tw1', 'US-Tw3', 'US-Tw4', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === US-ICs 处理完成（成功: True) ===
# 已完成总数: 11/79
# 剩余未处理: ['AT-Neu', 'BR-Npw', 'BW-Gum', 'BW-Nxr', 'CA-SCB', 'CA-SCC', 'CH-Cha', 'CH-Dav', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-SfN', 'DE-Zrk', 'FI-Hyy', 'FI-Lom', 'FI-Si2', 'FI-Sii', 'FR-LGt', 'HK-MPM', 'IT-BCi', 'IT-Cas', 'JP-BBY', 'JP-SwL', 'KR-CRK', 'MY-MLM', 'NL-Hor', 'NZ-Kop', 'PH-RiF', 'RU-Ch2', 'RU-Che', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-BZS', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-Bi2', 'US-CRT', 'US-DPW', 'US-EML', 'US-HRC', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-MAC', 'US-Myb', 'US-NC4', 'US-NGB', 'US-ORv', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Sne', 'US-Srr', 'US-StJ', 'US-Tw1', 'US-Tw3', 'US-Tw4', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === IT-Cas 处理完成（成功: True) ===
# 已完成总数: 12/79
# 剩余未处理: ['AT-Neu', 'BR-Npw', 'BW-Gum', 'BW-Nxr', 'CA-SCB', 'CA-SCC', 'CH-Cha', 'CH-Dav', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-SfN', 'DE-Zrk', 'FI-Hyy', 'FI-Lom', 'FI-Si2', 'FI-Sii', 'FR-LGt', 'HK-MPM', 'IT-BCi', 'JP-BBY', 'JP-SwL', 'KR-CRK', 'MY-MLM', 'NL-Hor', 'NZ-Kop', 'PH-RiF', 'RU-Ch2', 'RU-Che', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-BZS', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-Bi2', 'US-CRT', 'US-DPW', 'US-EML', 'US-HRC', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-MAC', 'US-Myb', 'US-NC4', 'US-NGB', 'US-ORv', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Sne', 'US-Srr', 'US-StJ', 'US-Tw1', 'US-Tw3', 'US-Tw4', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === MY-MLM 处理完成（成功: True) ===
# 已完成总数: 13/79
# 剩余未处理: ['AT-Neu', 'BR-Npw', 'BW-Gum', 'BW-Nxr', 'CA-SCB', 'CA-SCC', 'CH-Cha', 'CH-Dav', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-SfN', 'DE-Zrk', 'FI-Hyy', 'FI-Lom', 'FI-Si2', 'FI-Sii', 'FR-LGt', 'HK-MPM', 'IT-BCi', 'JP-BBY', 'JP-SwL', 'KR-CRK', 'NL-Hor', 'NZ-Kop', 'PH-RiF', 'RU-Ch2', 'RU-Che', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-BZS', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-Bi2', 'US-CRT', 'US-DPW', 'US-EML', 'US-HRC', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-MAC', 'US-Myb', 'US-NC4', 'US-NGB', 'US-ORv', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Sne', 'US-Srr', 'US-StJ', 'US-Tw1', 'US-Tw3', 'US-Tw4', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === CH-Dav 处理完成（成功: True) ===
# 已完成总数: 14/79
# 剩余未处理: ['AT-Neu', 'BR-Npw', 'BW-Gum', 'BW-Nxr', 'CA-SCB', 'CA-SCC', 'CH-Cha', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-SfN', 'DE-Zrk', 'FI-Hyy', 'FI-Lom', 'FI-Si2', 'FI-Sii', 'FR-LGt', 'HK-MPM', 'IT-BCi', 'JP-BBY', 'JP-SwL', 'KR-CRK', 'NL-Hor', 'NZ-Kop', 'PH-RiF', 'RU-Ch2', 'RU-Che', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-BZS', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-Bi2', 'US-CRT', 'US-DPW', 'US-EML', 'US-HRC', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-MAC', 'US-Myb', 'US-NC4', 'US-NGB', 'US-ORv', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Sne', 'US-Srr', 'US-StJ', 'US-Tw1', 'US-Tw3', 'US-Tw4', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === US-StJ 处理完成（成功: True) ===
# 已完成总数: 15/79
# 剩余未处理: ['AT-Neu', 'BR-Npw', 'BW-Gum', 'BW-Nxr', 'CA-SCB', 'CA-SCC', 'CH-Cha', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-SfN', 'DE-Zrk', 'FI-Hyy', 'FI-Lom', 'FI-Si2', 'FI-Sii', 'FR-LGt', 'HK-MPM', 'IT-BCi', 'JP-BBY', 'JP-SwL', 'KR-CRK', 'NL-Hor', 'NZ-Kop', 'PH-RiF', 'RU-Ch2', 'RU-Che', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-BZS', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-Bi2', 'US-CRT', 'US-DPW', 'US-EML', 'US-HRC', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-MAC', 'US-Myb', 'US-NC4', 'US-NGB', 'US-ORv', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Sne', 'US-Srr', 'US-Tw1', 'US-Tw3', 'US-Tw4', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === US-NGB 处理完成（成功: True) ===
# 已完成总数: 16/79
# 剩余未处理: ['AT-Neu', 'BR-Npw', 'BW-Gum', 'BW-Nxr', 'CA-SCB', 'CA-SCC', 'CH-Cha', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-SfN', 'DE-Zrk', 'FI-Hyy', 'FI-Lom', 'FI-Si2', 'FI-Sii', 'FR-LGt', 'HK-MPM', 'IT-BCi', 'JP-BBY', 'JP-SwL', 'KR-CRK', 'NL-Hor', 'NZ-Kop', 'PH-RiF', 'RU-Ch2', 'RU-Che', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-BZS', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-Bi2', 'US-CRT', 'US-DPW', 'US-EML', 'US-HRC', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-MAC', 'US-Myb', 'US-NC4', 'US-ORv', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Sne', 'US-Srr', 'US-Tw1', 'US-Tw3', 'US-Tw4', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === US-BZS 处理完成（成功: True) ===
# 已完成总数: 17/79
# 剩余未处理: ['AT-Neu', 'BR-Npw', 'BW-Gum', 'BW-Nxr', 'CA-SCB', 'CA-SCC', 'CH-Cha', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-SfN', 'DE-Zrk', 'FI-Hyy', 'FI-Lom', 'FI-Si2', 'FI-Sii', 'FR-LGt', 'HK-MPM', 'IT-BCi', 'JP-BBY', 'JP-SwL', 'KR-CRK', 'NL-Hor', 'NZ-Kop', 'PH-RiF', 'RU-Ch2', 'RU-Che', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-Bi2', 'US-CRT', 'US-DPW', 'US-EML', 'US-HRC', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-MAC', 'US-Myb', 'US-NC4', 'US-ORv', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Sne', 'US-Srr', 'US-Tw1', 'US-Tw3', 'US-Tw4', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === US-CRT 处理完成（成功: True) ===
# 已完成总数: 18/79
# 剩余未处理: ['AT-Neu', 'BR-Npw', 'BW-Gum', 'BW-Nxr', 'CA-SCB', 'CA-SCC', 'CH-Cha', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-SfN', 'DE-Zrk', 'FI-Hyy', 'FI-Lom', 'FI-Si2', 'FI-Sii', 'FR-LGt', 'HK-MPM', 'IT-BCi', 'JP-BBY', 'JP-SwL', 'KR-CRK', 'NL-Hor', 'NZ-Kop', 'PH-RiF', 'RU-Ch2', 'RU-Che', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-Bi2', 'US-DPW', 'US-EML', 'US-HRC', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-MAC', 'US-Myb', 'US-NC4', 'US-ORv', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Sne', 'US-Srr', 'US-Tw1', 'US-Tw3', 'US-Tw4', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === AT-Neu 处理完成（成功: True) ===
# 已完成总数: 19/79
# 剩余未处理: ['BR-Npw', 'BW-Gum', 'BW-Nxr', 'CA-SCB', 'CA-SCC', 'CH-Cha', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-SfN', 'DE-Zrk', 'FI-Hyy', 'FI-Lom', 'FI-Si2', 'FI-Sii', 'FR-LGt', 'HK-MPM', 'IT-BCi', 'JP-BBY', 'JP-SwL', 'KR-CRK', 'NL-Hor', 'NZ-Kop', 'PH-RiF', 'RU-Ch2', 'RU-Che', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-Bi2', 'US-DPW', 'US-EML', 'US-HRC', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-MAC', 'US-Myb', 'US-NC4', 'US-ORv', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Sne', 'US-Srr', 'US-Tw1', 'US-Tw3', 'US-Tw4', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === RU-Ch2 处理完成（成功: True) ===
# 已完成总数: 20/79
# 剩余未处理: ['BR-Npw', 'BW-Gum', 'BW-Nxr', 'CA-SCB', 'CA-SCC', 'CH-Cha', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-SfN', 'DE-Zrk', 'FI-Hyy', 'FI-Lom', 'FI-Si2', 'FI-Sii', 'FR-LGt', 'HK-MPM', 'IT-BCi', 'JP-BBY', 'JP-SwL', 'KR-CRK', 'NL-Hor', 'NZ-Kop', 'PH-RiF', 'RU-Che', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-Bi2', 'US-DPW', 'US-EML', 'US-HRC', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-MAC', 'US-Myb', 'US-NC4', 'US-ORv', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Sne', 'US-Srr', 'US-Tw1', 'US-Tw3', 'US-Tw4', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === DE-SfN 处理完成（成功: True) ===
# 已完成总数: 21/79
# 剩余未处理: ['BR-Npw', 'BW-Gum', 'BW-Nxr', 'CA-SCB', 'CA-SCC', 'CH-Cha', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-Zrk', 'FI-Hyy', 'FI-Lom', 'FI-Si2', 'FI-Sii', 'FR-LGt', 'HK-MPM', 'IT-BCi', 'JP-BBY', 'JP-SwL', 'KR-CRK', 'NL-Hor', 'NZ-Kop', 'PH-RiF', 'RU-Che', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-Bi2', 'US-DPW', 'US-EML', 'US-HRC', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-MAC', 'US-Myb', 'US-NC4', 'US-ORv', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Sne', 'US-Srr', 'US-Tw1', 'US-Tw3', 'US-Tw4', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === US-EML 处理完成（成功: True) ===
# 已完成总数: 22/79
# 剩余未处理: ['BR-Npw', 'BW-Gum', 'BW-Nxr', 'CA-SCB', 'CA-SCC', 'CH-Cha', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-Zrk', 'FI-Hyy', 'FI-Lom', 'FI-Si2', 'FI-Sii', 'FR-LGt', 'HK-MPM', 'IT-BCi', 'JP-BBY', 'JP-SwL', 'KR-CRK', 'NL-Hor', 'NZ-Kop', 'PH-RiF', 'RU-Che', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-Bi2', 'US-DPW', 'US-HRC', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-MAC', 'US-Myb', 'US-NC4', 'US-ORv', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Sne', 'US-Srr', 'US-Tw1', 'US-Tw3', 'US-Tw4', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === FR-LGt 处理完成（成功: True) ===
# 已完成总数: 23/79
# 剩余未处理: ['BR-Npw', 'BW-Gum', 'BW-Nxr', 'CA-SCB', 'CA-SCC', 'CH-Cha', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-Zrk', 'FI-Hyy', 'FI-Lom', 'FI-Si2', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'JP-BBY', 'JP-SwL', 'KR-CRK', 'NL-Hor', 'NZ-Kop', 'PH-RiF', 'RU-Che', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-Bi2', 'US-DPW', 'US-HRC', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-MAC', 'US-Myb', 'US-NC4', 'US-ORv', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Sne', 'US-Srr', 'US-Tw1', 'US-Tw3', 'US-Tw4', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === KR-CRK 处理完成（成功: True) ===
# 已完成总数: 24/79
# 剩余未处理: ['BR-Npw', 'BW-Gum', 'BW-Nxr', 'CA-SCB', 'CA-SCC', 'CH-Cha', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-Zrk', 'FI-Hyy', 'FI-Lom', 'FI-Si2', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'JP-BBY', 'JP-SwL', 'NL-Hor', 'NZ-Kop', 'PH-RiF', 'RU-Che', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-Bi2', 'US-DPW', 'US-HRC', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-MAC', 'US-Myb', 'US-NC4', 'US-ORv', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Sne', 'US-Srr', 'US-Tw1', 'US-Tw3', 'US-Tw4', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === BW-Gum 处理完成（成功: True) ===
# 已完成总数: 25/79
# 剩余未处理: ['BR-Npw', 'BW-Nxr', 'CA-SCB', 'CA-SCC', 'CH-Cha', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-Zrk', 'FI-Hyy', 'FI-Lom', 'FI-Si2', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'JP-BBY', 'JP-SwL', 'NL-Hor', 'NZ-Kop', 'PH-RiF', 'RU-Che', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-Bi2', 'US-DPW', 'US-HRC', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-MAC', 'US-Myb', 'US-NC4', 'US-ORv', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Sne', 'US-Srr', 'US-Tw1', 'US-Tw3', 'US-Tw4', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === FI-Lom 处理完成（成功: True) ===
# 已完成总数: 26/79
# 剩余未处理: ['BR-Npw', 'BW-Nxr', 'CA-SCB', 'CA-SCC', 'CH-Cha', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-Zrk', 'FI-Hyy', 'FI-Si2', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'JP-BBY', 'JP-SwL', 'NL-Hor', 'NZ-Kop', 'PH-RiF', 'RU-Che', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-Bi2', 'US-DPW', 'US-HRC', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-MAC', 'US-Myb', 'US-NC4', 'US-ORv', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Sne', 'US-Srr', 'US-Tw1', 'US-Tw3', 'US-Tw4', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === JP-SwL 处理完成（成功: True) ===
# 已完成总数: 27/79
# 剩余未处理: ['BR-Npw', 'BW-Nxr', 'CA-SCB', 'CA-SCC', 'CH-Cha', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-Zrk', 'FI-Hyy', 'FI-Si2', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'JP-BBY', 'NL-Hor', 'NZ-Kop', 'PH-RiF', 'RU-Che', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-Bi2', 'US-DPW', 'US-HRC', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-MAC', 'US-Myb', 'US-NC4', 'US-ORv', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Sne', 'US-Srr', 'US-Tw1', 'US-Tw3', 'US-Tw4', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === FI-Si2 处理完成（成功: True) ===
# 已完成总数: 28/79
# 剩余未处理: ['BR-Npw', 'BW-Nxr', 'CA-SCB', 'CA-SCC', 'CH-Cha', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-Zrk', 'FI-Hyy', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'JP-BBY', 'NL-Hor', 'NZ-Kop', 'PH-RiF', 'RU-Che', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-Bi2', 'US-DPW', 'US-HRC', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-MAC', 'US-Myb', 'US-NC4', 'US-ORv', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Sne', 'US-Srr', 'US-Tw1', 'US-Tw3', 'US-Tw4', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === US-Sne 处理完成（成功: True) ===
# 已完成总数: 29/79
# 剩余未处理: ['BR-Npw', 'BW-Nxr', 'CA-SCB', 'CA-SCC', 'CH-Cha', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-Zrk', 'FI-Hyy', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'JP-BBY', 'NL-Hor', 'NZ-Kop', 'PH-RiF', 'RU-Che', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-Bi2', 'US-DPW', 'US-HRC', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-MAC', 'US-Myb', 'US-NC4', 'US-ORv', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Srr', 'US-Tw1', 'US-Tw3', 'US-Tw4', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === PH-RiF 处理完成（成功: True) ===
# 已完成总数: 30/79
# 剩余未处理: ['BR-Npw', 'BW-Nxr', 'CA-SCB', 'CA-SCC', 'CH-Cha', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-Zrk', 'FI-Hyy', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'JP-BBY', 'NL-Hor', 'NZ-Kop', 'RU-Che', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-Bi2', 'US-DPW', 'US-HRC', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-MAC', 'US-Myb', 'US-NC4', 'US-ORv', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Srr', 'US-Tw1', 'US-Tw3', 'US-Tw4', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === CH-Cha 处理完成（成功: True) ===
# 已完成总数: 31/79
# 剩余未处理: ['BR-Npw', 'BW-Nxr', 'CA-SCB', 'CA-SCC', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-Zrk', 'FI-Hyy', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'JP-BBY', 'NL-Hor', 'NZ-Kop', 'RU-Che', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-Bi2', 'US-DPW', 'US-HRC', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-MAC', 'US-Myb', 'US-NC4', 'US-ORv', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Srr', 'US-Tw1', 'US-Tw3', 'US-Tw4', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === US-ORv 处理完成（成功: True) ===
# 已完成总数: 32/79
# 剩余未处理: ['BR-Npw', 'BW-Nxr', 'CA-SCB', 'CA-SCC', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-Zrk', 'FI-Hyy', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'JP-BBY', 'NL-Hor', 'NZ-Kop', 'RU-Che', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-Bi2', 'US-DPW', 'US-HRC', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-MAC', 'US-Myb', 'US-NC4', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Srr', 'US-Tw1', 'US-Tw3', 'US-Tw4', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === US-Bi2 处理完成（成功: True) ===
# 已完成总数: 33/79
# 剩余未处理: ['BR-Npw', 'BW-Nxr', 'CA-SCB', 'CA-SCC', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-Zrk', 'FI-Hyy', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'JP-BBY', 'NL-Hor', 'NZ-Kop', 'RU-Che', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-DPW', 'US-HRC', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-MAC', 'US-Myb', 'US-NC4', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Srr', 'US-Tw1', 'US-Tw3', 'US-Tw4', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === CA-SCB 处理完成（成功: True) ===
# 已完成总数: 34/79
# 剩余未处理: ['BR-Npw', 'BW-Nxr', 'CA-SCC', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-Zrk', 'FI-Hyy', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'JP-BBY', 'NL-Hor', 'NZ-Kop', 'RU-Che', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-DPW', 'US-HRC', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-MAC', 'US-Myb', 'US-NC4', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Srr', 'US-Tw1', 'US-Tw3', 'US-Tw4', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === US-Tw4 处理完成（成功: True) ===
# 已完成总数: 35/79
# 剩余未处理: ['BR-Npw', 'BW-Nxr', 'CA-SCC', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-Zrk', 'FI-Hyy', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'JP-BBY', 'NL-Hor', 'NZ-Kop', 'RU-Che', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-DPW', 'US-HRC', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-MAC', 'US-Myb', 'US-NC4', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Srr', 'US-Tw1', 'US-Tw3', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === US-DPW 处理完成（成功: True) ===
# 已完成总数: 36/79
# 剩余未处理: ['BR-Npw', 'BW-Nxr', 'CA-SCC', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-Zrk', 'FI-Hyy', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'JP-BBY', 'NL-Hor', 'NZ-Kop', 'RU-Che', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-HRC', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-MAC', 'US-Myb', 'US-NC4', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Srr', 'US-Tw1', 'US-Tw3', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === RU-Che 处理完成（成功: True) ===
# 已完成总数: 37/79
# 剩余未处理: ['BR-Npw', 'BW-Nxr', 'CA-SCC', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-Zrk', 'FI-Hyy', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'JP-BBY', 'NL-Hor', 'NZ-Kop', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-HRC', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-MAC', 'US-Myb', 'US-NC4', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Srr', 'US-Tw1', 'US-Tw3', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === US-Tw3 处理完成（成功: True) ===
# 已完成总数: 38/79
# 剩余未处理: ['BR-Npw', 'BW-Nxr', 'CA-SCC', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-Zrk', 'FI-Hyy', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'JP-BBY', 'NL-Hor', 'NZ-Kop', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-HRC', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-MAC', 'US-Myb', 'US-NC4', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Srr', 'US-Tw1', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === FI-Hyy 处理完成（成功: True) ===
# 已完成总数: 39/79
# 剩余未处理: ['BR-Npw', 'BW-Nxr', 'CA-SCC', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-Zrk', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'JP-BBY', 'NL-Hor', 'NZ-Kop', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-HRC', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-MAC', 'US-Myb', 'US-NC4', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Srr', 'US-Tw1', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === CA-SCC 处理完成（成功: True) ===
# 已完成总数: 40/79
# 剩余未处理: ['BR-Npw', 'BW-Nxr', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-Zrk', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'JP-BBY', 'NL-Hor', 'NZ-Kop', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-HRC', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-MAC', 'US-Myb', 'US-NC4', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Srr', 'US-Tw1', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === US-Srr 处理完成（成功: True) ===
# 已完成总数: 41/79
# 剩余未处理: ['BR-Npw', 'BW-Nxr', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-Zrk', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'JP-BBY', 'NL-Hor', 'NZ-Kop', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-HRC', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-MAC', 'US-Myb', 'US-NC4', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Tw1', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === NZ-Kop 处理完成（成功: True) ===
# 已完成总数: 42/79
# 剩余未处理: ['BR-Npw', 'BW-Nxr', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-Zrk', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'JP-BBY', 'NL-Hor', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-HRC', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-MAC', 'US-Myb', 'US-NC4', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Tw1', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === US-Tw1 处理完成（成功: True) ===
# 已完成总数: 43/79
# 剩余未处理: ['BR-Npw', 'BW-Nxr', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-Zrk', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'JP-BBY', 'NL-Hor', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-A10', 'US-Atq', 'US-BZB', 'US-BZF', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-HRC', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-MAC', 'US-Myb', 'US-NC4', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === US-A10 处理完成（成功: True) ===
# 已完成总数: 44/79
# 剩余未处理: ['BR-Npw', 'BW-Nxr', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-Zrk', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'JP-BBY', 'NL-Hor', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-Atq', 'US-BZB', 'US-BZF', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-HRC', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-MAC', 'US-Myb', 'US-NC4', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === US-BZF 处理完成（成功: True) ===
# 已完成总数: 45/79
# 剩余未处理: ['BR-Npw', 'BW-Nxr', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-Zrk', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'JP-BBY', 'NL-Hor', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-Atq', 'US-BZB', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-HRC', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-MAC', 'US-Myb', 'US-NC4', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === US-MAC 处理完成（成功: True) ===
# 已完成总数: 46/79
# 剩余未处理: ['BR-Npw', 'BW-Nxr', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-Zrk', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'JP-BBY', 'NL-Hor', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-Atq', 'US-BZB', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-HRC', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-Myb', 'US-NC4', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === BR-Npw 处理完成（成功: True) ===
# 已完成总数: 47/79
# 剩余未处理: ['BW-Nxr', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-Zrk', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'JP-BBY', 'NL-Hor', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-Atq', 'US-BZB', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-HRC', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-Myb', 'US-NC4', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === US-HRC 处理完成（成功: True) ===
# 已完成总数: 48/79
# 剩余未处理: ['BW-Nxr', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-Zrk', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'JP-BBY', 'NL-Hor', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-Atq', 'US-BZB', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-Myb', 'US-NC4', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Twt', 'US-Uaf', 'US-WPT']
# --------------------------------------------------
# === US-Uaf 处理完成（成功: True) ===
# 已完成总数: 49/79
# 剩余未处理: ['BW-Nxr', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-Zrk', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'JP-BBY', 'NL-Hor', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-Atq', 'US-BZB', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-Myb', 'US-NC4', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Twt', 'US-WPT']
# --------------------------------------------------
# === US-Myb 处理完成（成功: True) ===
# 已完成总数: 50/79
# 剩余未处理: ['BW-Nxr', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-Zrk', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'JP-BBY', 'NL-Hor', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-Atq', 'US-BZB', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-NC4', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Twt', 'US-WPT']
# --------------------------------------------------
# === JP-BBY 处理完成（成功: True) ===
# 已完成总数: 51/79
# 剩余未处理: ['BW-Nxr', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-Zrk', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'NL-Hor', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-Atq', 'US-BZB', 'US-Beo', 'US-Bes', 'US-Bi1', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-NC4', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Twt', 'US-WPT']
# --------------------------------------------------
# === US-Bes 处理完成（成功: True) ===
# 已完成总数: 52/79
# 剩余未处理: ['BW-Nxr', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-Zrk', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'NL-Hor', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-Atq', 'US-BZB', 'US-Beo', 'US-Bi1', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-NC4', 'US-OWC', 'US-Pfa', 'US-Snd', 'US-Twt', 'US-WPT']
# --------------------------------------------------
# === US-Snd 处理完成（成功: True) ===
# 已完成总数: 53/79
# 剩余未处理: ['BW-Nxr', 'CH-Oe2', 'CN-Hgu', 'DE-Hte', 'DE-Zrk', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'NL-Hor', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-Atq', 'US-BZB', 'US-Beo', 'US-Bi1', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-NC4', 'US-OWC', 'US-Pfa', 'US-Twt', 'US-WPT']
# --------------------------------------------------
# === CH-Oe2 处理完成（成功: True) ===
# 已完成总数: 54/79
# 剩余未处理: ['BW-Nxr', 'CN-Hgu', 'DE-Hte', 'DE-Zrk', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'NL-Hor', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-Atq', 'US-BZB', 'US-Beo', 'US-Bi1', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-NC4', 'US-OWC', 'US-Pfa', 'US-Twt', 'US-WPT']
# --------------------------------------------------
# === US-Bi1 处理完成（成功: True) ===
# 已完成总数: 55/79
# 剩余未处理: ['BW-Nxr', 'CN-Hgu', 'DE-Hte', 'DE-Zrk', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'NL-Hor', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'UK-LBT', 'US-A03', 'US-Atq', 'US-BZB', 'US-Beo', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-NC4', 'US-OWC', 'US-Pfa', 'US-Twt', 'US-WPT']
# --------------------------------------------------
# === UK-LBT 处理完成（成功: True) ===
# 已完成总数: 56/79
# 剩余未处理: ['BW-Nxr', 'CN-Hgu', 'DE-Hte', 'DE-Zrk', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'NL-Hor', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'US-A03', 'US-Atq', 'US-BZB', 'US-Beo', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-NC4', 'US-OWC', 'US-Pfa', 'US-Twt', 'US-WPT']
# --------------------------------------------------
# === US-A03 处理完成（成功: True) ===
# 已完成总数: 57/79
# 剩余未处理: ['BW-Nxr', 'CN-Hgu', 'DE-Hte', 'DE-Zrk', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'NL-Hor', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'US-Atq', 'US-BZB', 'US-Beo', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-NC4', 'US-OWC', 'US-Pfa', 'US-Twt', 'US-WPT']
# --------------------------------------------------
# === BW-Nxr 处理完成（成功: True) ===
# 已完成总数: 58/79
# 剩余未处理: ['CN-Hgu', 'DE-Hte', 'DE-Zrk', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'NL-Hor', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'US-Atq', 'US-BZB', 'US-Beo', 'US-Ho1', 'US-Ivo', 'US-Los', 'US-NC4', 'US-OWC', 'US-Pfa', 'US-Twt', 'US-WPT']
# --------------------------------------------------
# === US-Ivo 处理完成（成功: True) ===
# 已完成总数: 59/79
# 剩余未处理: ['CN-Hgu', 'DE-Hte', 'DE-Zrk', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'NL-Hor', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'US-Atq', 'US-BZB', 'US-Beo', 'US-Ho1', 'US-Los', 'US-NC4', 'US-OWC', 'US-Pfa', 'US-Twt', 'US-WPT']
# --------------------------------------------------
# === US-WPT 处理完成（成功: True) ===
# 已完成总数: 60/79
# 剩余未处理: ['CN-Hgu', 'DE-Hte', 'DE-Zrk', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'NL-Hor', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'US-Atq', 'US-BZB', 'US-Beo', 'US-Ho1', 'US-Los', 'US-NC4', 'US-OWC', 'US-Pfa', 'US-Twt']
# --------------------------------------------------
# === US-Beo 处理完成（成功: True) ===
# 已完成总数: 61/79
# 剩余未处理: ['CN-Hgu', 'DE-Hte', 'DE-Zrk', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'NL-Hor', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'US-Atq', 'US-BZB', 'US-Ho1', 'US-Los', 'US-NC4', 'US-OWC', 'US-Pfa', 'US-Twt']
# --------------------------------------------------
# === CN-Hgu 处理完成（成功: True) ===
# 已完成总数: 62/79
# 剩余未处理: ['DE-Hte', 'DE-Zrk', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'NL-Hor', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'US-Atq', 'US-BZB', 'US-Ho1', 'US-Los', 'US-NC4', 'US-OWC', 'US-Pfa', 'US-Twt']
# --------------------------------------------------
# === US-BZB 处理完成（成功: True) ===
# 已完成总数: 63/79
# 剩余未处理: ['DE-Hte', 'DE-Zrk', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'NL-Hor', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'US-Atq', 'US-Ho1', 'US-Los', 'US-NC4', 'US-OWC', 'US-Pfa', 'US-Twt']
# --------------------------------------------------
# === US-Los 处理完成（成功: True) ===
# 已完成总数: 64/79
# 剩余未处理: ['DE-Hte', 'DE-Zrk', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'NL-Hor', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'US-Atq', 'US-Ho1', 'US-NC4', 'US-OWC', 'US-Pfa', 'US-Twt']
# --------------------------------------------------
# === US-OWC 处理完成（成功: True) ===
# 已完成总数: 65/79
# 剩余未处理: ['DE-Hte', 'DE-Zrk', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'NL-Hor', 'RU-Cok', 'RU-Fy2', 'SE-Deg', 'US-Atq', 'US-Ho1', 'US-NC4', 'US-Pfa', 'US-Twt']
# --------------------------------------------------
# === RU-Fy2 处理完成（成功: True) ===
# 已完成总数: 66/79
# 剩余未处理: ['DE-Hte', 'DE-Zrk', 'FI-Sii', 'HK-MPM', 'IT-BCi', 'NL-Hor', 'RU-Cok', 'SE-Deg', 'US-Atq', 'US-Ho1', 'US-NC4', 'US-Pfa', 'US-Twt']
# --------------------------------------------------
# === IT-BCi 处理完成（成功: True) ===
# 已完成总数: 67/79
# 剩余未处理: ['DE-Hte', 'DE-Zrk', 'FI-Sii', 'HK-MPM', 'NL-Hor', 'RU-Cok', 'SE-Deg', 'US-Atq', 'US-Ho1', 'US-NC4', 'US-Pfa', 'US-Twt']
# --------------------------------------------------
# === NL-Hor 处理完成（成功: True) ===
# 已完成总数: 68/79
# 剩余未处理: ['DE-Hte', 'DE-Zrk', 'FI-Sii', 'HK-MPM', 'RU-Cok', 'SE-Deg', 'US-Atq', 'US-Ho1', 'US-NC4', 'US-Pfa', 'US-Twt']
# --------------------------------------------------
# === RU-Cok 处理完成（成功: True) ===
# 已完成总数: 69/79
# 剩余未处理: ['DE-Hte', 'DE-Zrk', 'FI-Sii', 'HK-MPM', 'SE-Deg', 'US-Atq', 'US-Ho1', 'US-NC4', 'US-Pfa', 'US-Twt']
# --------------------------------------------------
# === US-Ho1 处理完成（成功: True) ===
# 已完成总数: 70/79
# 剩余未处理: ['DE-Hte', 'DE-Zrk', 'FI-Sii', 'HK-MPM', 'SE-Deg', 'US-Atq', 'US-NC4', 'US-Pfa', 'US-Twt']
# --------------------------------------------------
# === US-Atq 处理完成（成功: True) ===
# 已完成总数: 71/79
# 剩余未处理: ['DE-Hte', 'DE-Zrk', 'FI-Sii', 'HK-MPM', 'SE-Deg', 'US-NC4', 'US-Pfa', 'US-Twt']
# --------------------------------------------------
# === DE-Hte 处理完成（成功: True) ===
# 已完成总数: 72/79
# 剩余未处理: ['DE-Zrk', 'FI-Sii', 'HK-MPM', 'SE-Deg', 'US-NC4', 'US-Pfa', 'US-Twt']
# --------------------------------------------------
# === US-NC4 处理完成（成功: True) ===
# 已完成总数: 73/79
# 剩余未处理: ['DE-Zrk', 'FI-Sii', 'HK-MPM', 'SE-Deg', 'US-Pfa', 'US-Twt']
# --------------------------------------------------
# === DE-Zrk 处理完成（成功: True) ===
# 已完成总数: 74/79
# 剩余未处理: ['FI-Sii', 'HK-MPM', 'SE-Deg', 'US-Pfa', 'US-Twt']
# --------------------------------------------------
# === SE-Deg 处理完成（成功: True) ===
# 已完成总数: 75/79
# 剩余未处理: ['FI-Sii', 'HK-MPM', 'US-Pfa', 'US-Twt']
# --------------------------------------------------
# === FI-Sii 处理完成（成功: True) ===
# 已完成总数: 76/79
# 剩余未处理: ['HK-MPM', 'US-Pfa', 'US-Twt']
# --------------------------------------------------
# === US-Pfa 处理完成（成功: True) ===
# 已完成总数: 77/79
# 剩余未处理: ['HK-MPM', 'US-Twt']
# --------------------------------------------------
# === US-Twt 处理完成（成功: True) ===
# 已完成总数: 78/79
# 剩余未处理: ['HK-MPM']
# --------------------------------------------------
# Process ForkProcess-55:
# Process ForkProcess-64:
# Process ForkProcess-53:
# Process ForkProcess-62:
# Process ForkProcess-51:
# Process ForkProcess-58:
# Process ForkProcess-56:
# Process ForkProcess-72:
# Process ForkProcess-49:
# Process ForkProcess-63:
# Process ForkProcess-68:
# Process ForkProcess-61:
# Process ForkProcess-71:
# Process ForkProcess-52:
# Process ForkProcess-67:
# Process ForkProcess-65:
# Process ForkProcess-59:
# Process ForkProcess-57:
# Process ForkProcess-66:
# Process ForkProcess-60:
# Process ForkProcess-50:
# Traceback (most recent call last):
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/concurrent/futures/process.py", line 242, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/queues.py", line 100, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/concurrent/futures/process.py", line 242, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/concurrent/futures/process.py", line 242, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/concurrent/futures/process.py", line 242, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/concurrent/futures/process.py", line 242, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/concurrent/futures/process.py", line 242, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/queues.py", line 100, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/concurrent/futures/process.py", line 242, in _process_worker
#     call_item = call_queue.get(block=True)
# Process ForkProcess-70:
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/concurrent/futures/process.py", line 242, in _process_worker
#     call_item = call_queue.get(block=True)
# KeyboardInterrupt
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/concurrent/futures/process.py", line 242, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/queues.py", line 100, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/concurrent/futures/process.py", line 242, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/concurrent/futures/process.py", line 242, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/queues.py", line 100, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/concurrent/futures/process.py", line 242, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/queues.py", line 100, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/concurrent/futures/process.py", line 242, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/concurrent/futures/process.py", line 242, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/concurrent/futures/process.py", line 242, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/queues.py", line 100, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/concurrent/futures/process.py", line 242, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/concurrent/futures/process.py", line 242, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/queues.py", line 100, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/concurrent/futures/process.py", line 242, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/queues.py", line 100, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/queues.py", line 100, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/queues.py", line 100, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/queues.py", line 100, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/queues.py", line 100, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/concurrent/futures/process.py", line 242, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/queues.py", line 100, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/queues.py", line 100, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/queues.py", line 100, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/concurrent/futures/process.py", line 242, in _process_worker
#     call_item = call_queue.get(block=True)
# KeyboardInterrupt
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/queues.py", line 100, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/queues.py", line 100, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/concurrent/futures/process.py", line 242, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/queues.py", line 100, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/queues.py", line 100, in get
#     with self._rlock:
#          ^^^^^^^^^^^
# KeyboardInterrupt
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# Traceback (most recent call last):
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/queues.py", line 100, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/queues.py", line 101, in get
#     res = self._recv_bytes()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
# KeyboardInterrupt
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/concurrent/futures/process.py", line 242, in _process_worker
#     call_item = call_queue.get(block=True)
# KeyboardInterrupt
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/queues.py", line 100, in get
#     with self._rlock:
#          ^^^^^^^^^^^
# Process ForkProcess-69:
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/concurrent/futures/process.py", line 242, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/queues.py", line 100, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/share/home/dq076/software/miniconda3/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 93
#      90 completed_count = 0
#      92 # 实时监控完成
# ---> 93 for future in as_completed(future_to_nml):
#      94     nml_name = future_to_nml[future]
#      95     try:
#
# File ~/software/miniconda3/lib/python3.13/concurrent/futures/_base.py:243, in as_completed(fs, timeout)
#     238     if wait_timeout < 0:
#     239         raise TimeoutError(
#     240                 '%d (of %d) futures unfinished' % (
#     241                 len(pending), total_futures))
# --> 243 waiter.event.wait(wait_timeout)
#     245 with waiter.lock:
#     246     finished = waiter.finished_futures
#
# File ~/software/miniconda3/lib/python3.13/threading.py:659, in Event.wait(self, timeout)
#     657 signaled = self._flag
#     658 if not signaled:
# --> 659     signaled = self._cond.wait(timeout)
#     660 return signaled
#
# File ~/software/miniconda3/lib/python3.13/threading.py:359, in Condition.wait(self, timeout)
#     357 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     358     if timeout is None:
# --> 359         waiter.acquire()
#     360         gotit = True
#     361     else:
#
# KeyboardInterrupt:
